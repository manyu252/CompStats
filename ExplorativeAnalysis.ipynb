# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
data=pd.read_csv('a1_data.csv')
data.head()
print('The number of rows in the dataset is',data.shape[0])
print('The number of columns in the dataset is',data.shape[1])
# Out:
# The number of rows in the dataset is 11672
# The number of columns in the dataset is 11

# %%
data.corr()
# Out:
#           A         B         C         D         E         F         G  \
# A  1.000000  0.732754  0.059749  0.046837  0.030800  0.005910 -0.004302
# B  0.732754  1.000000 -0.035690  0.042475 -0.006696  0.083634  0.071430
# C  0.059749 -0.035690  1.000000  0.122102  0.135895 -0.065264 -0.063552
# D  0.046837  0.042475  0.122102  1.000000  0.225912 -0.010855 -0.013759
# E  0.030800 -0.006696  0.135895  0.225912  1.000000  0.032065 -0.002100
# F  0.005910  0.083634 -0.065264 -0.010855  0.032065  1.000000  0.902994
# G -0.004302  0.071430 -0.063552 -0.013759 -0.002100  0.902994  1.000000
# H  0.083669  0.048366  0.014767  0.010978  0.124299  0.259596  0.226368
# I  0.021806  0.068700  0.011183 -0.007702  0.047123  0.023248 -0.004076
# J -0.062399  0.121626 -0.047029 -0.036118  0.021638  0.172260  0.146384
# K -0.056897  0.025165 -0.039341  0.011274  0.057507  0.001654 -0.042084
#
#           H         I         J         K
# A  0.083669  0.021806 -0.062399 -0.056897
# B  0.048366  0.068700  0.121626  0.025165
# C  0.014767  0.011183 -0.047029 -0.039341
# D  0.010978 -0.007702 -0.036118  0.011274
# E  0.124299  0.047123  0.021638  0.057507
# F  0.259596  0.023248  0.172260  0.001654
# G  0.226368 -0.004076  0.146384 -0.042084
# H  1.000000  0.150639 -0.059614  0.087830
# I  0.150639  1.000000  0.488495  0.210998
# J -0.059614  0.488495  1.000000  0.122510
# K  0.087830  0.210998  0.122510  1.000000

# %%
plt.figure(figsize=(20,15))
corr_matrix = data.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
# change the size of the plot   
plt.show()

# %%
# plot the histogram of the data
data.hist(bins=50, figsize=(20,15))
plt.show()

# %%
#covariance matrix of the data
cov_matrix =data.cov()
plt.figure(figsize=(20,15))
sns.heatmap(cov_matrix, annot=True, fmt='g')

plt.show()
